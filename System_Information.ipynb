# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/RaulMedeiros/Colab_Snippets/blob/master/System_Information.ipynb)

# %% [markdown]
# ## System Information

# %%
# !/sbin/ldconfig -p
# Out:
# 259 libs found in cache `/etc/ld.so.cache'
# 	libzmq.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libzmq.so.5
# 	libz.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libz.so.1
# 	libz.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libz.so
# 	libxml2.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libxml2.so.2
# 	libxml2.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libxml2.so
# 	libxcb.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libxcb.so.1
# 	libxcb.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libxcb.so
# 	libwind.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libwind.so.0
# 	libuuid.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libuuid.so.1
# 	libutil.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libutil.so.1
# 	libutil.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libutil.so
# 	libunwind.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libunwind.so.8
# 	libunwind-x86_64.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libunwind-x86_64.so.8
# 	libunwind-ptrace.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libunwind-ptrace.so.0
# 	libunwind-coredump.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libunwind-coredump.so.0
# 	libunistring.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libunistring.so.0
# 	libudev.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libudev.so.1
# 	libubsan.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libubsan.so.0
# 	libtsan.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtsan.so.0
# 	libtk8.6.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtk8.6.so
# 	libtinfo.so.5 (libc6,x86-64) => /lib/x86_64-linux-gnu/libtinfo.so.5
# 	libtic.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtic.so.5
# 	libthread_db.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libthread_db.so.1
# 	libthread_db.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libthread_db.so
# 	libtcmalloc_minimal_debug.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcmalloc_minimal_debug.so.4
# 	libtcmalloc_minimal.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcmalloc_minimal.so.4
# 	libtcmalloc_debug.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcmalloc_debug.so.4
# 	libtcmalloc_and_profiler.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcmalloc_and_profiler.so.4
# 	libtcmalloc.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcmalloc.so.4
# 	libtcl8.6.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtcl8.6.so
# 	libtasn1.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libtasn1.so.6
# 	libsz.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsz.so.2
# 	libsz.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsz.so
# 	libsystemd.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libsystemd.so.0
# 	libstdc++.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libstdc++.so.6
# 	libssl.so.1.0.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libssl.so.1.0.0
# 	libss.so.2 (libc6,x86-64) => /lib/x86_64-linux-gnu/libss.so.2
# 	libsqlite3.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsqlite3.so.0
# 	libsodium.so.18 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsodium.so.18
# 	libsmartcols.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libsmartcols.so.1
# 	libsepol.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libsepol.so.1
# 	libsemanage.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsemanage.so.1
# 	libselinux.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libselinux.so.1
# 	libsasl2.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libsasl2.so.2
# 	librtmp.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/librtmp.so.1
# 	librt.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/librt.so.1
# 	librt.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/librt.so
# 	libroken.so.18 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libroken.so.18
# 	libresolv.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libresolv.so.2
# 	libresolv.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libresolv.so
# 	libreadline.so.7 (libc6,x86-64) => /lib/x86_64-linux-gnu/libreadline.so.7
# 	libquadmath.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libquadmath.so.0
# 	libp11-kit.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libp11-kit.so.0
# 	libpython3.6m.so.1.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpython3.6m.so.1.0
# 	libpython3.6m.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpython3.6m.so
# 	libpython2.7.so.1.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpython2.7.so.1.0
# 	libpython2.7.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpython2.7.so
# 	libpthread.so.0 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libpthread.so.0
# 	libpsl.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpsl.so.5
# 	libprofiler.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libprofiler.so.0
# 	libprocps.so.6 (libc6,x86-64) => /lib/x86_64-linux-gnu/libprocps.so.6
# 	libpopt.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libpopt.so.0
# 	libpng16.so.16 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpng16.so.16
# 	libpng16.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpng16.so
# 	libpgm-5.2.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpgm-5.2.so.0
# 	libperl.so.5.26 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libperl.so.5.26
# 	libpcreposix.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpcreposix.so.3
# 	libpcre.so.3 (libc6,x86-64) => /lib/x86_64-linux-gnu/libpcre.so.3
# 	libpcprofile.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libpcprofile.so
# 	libpanelw.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpanelw.so.5
# 	libpanel.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libpanel.so.5
# 	libpamc.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libpamc.so.0
# 	libpam_misc.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libpam_misc.so.0
# 	libpam.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libpam.so.0
# 	libopcodes-2.29.1-system.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libopcodes-2.29.1-system.so
# 	libnss_nisplus.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_nisplus.so.2
# 	libnss_nisplus.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_nisplus.so
# 	libnss_nis.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_nis.so.2
# 	libnss_nis.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_nis.so
# 	libnss_hesiod.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_hesiod.so.2
# 	libnss_hesiod.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_hesiod.so
# 	libnss_files.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_files.so.2
# 	libnss_files.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_files.so
# 	libnss_dns.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_dns.so.2
# 	libnss_dns.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_dns.so
# 	libnss_compat.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnss_compat.so.2
# 	libnss_compat.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnss_compat.so
# 	libnsl.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libnsl.so.1
# 	libnsl.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libnsl.so
# 	libnpth.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libnpth.so.0
# 	libnettle.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libnettle.so.6
# 	libncursesw.so.5 (libc6,x86-64) => /lib/x86_64-linux-gnu/libncursesw.so.5
# 	libncurses.so.5 (libc6,x86-64) => /lib/x86_64-linux-gnu/libncurses.so.5
# 	libmvec.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libmvec.so.1
# 	libmvec.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libmvec.so
# 	libmpxwrappers.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmpxwrappers.so.2
# 	libmpx.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmpx.so.2
# 	libmpfr.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmpfr.so.4
# 	libmpdec.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmpdec.so.2
# 	libmpc.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmpc.so.3
# 	libmount.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libmount.so.1
# 	libmenuw.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmenuw.so.5
# 	libmenu.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libmenu.so.5
# 	libmemusage.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libmemusage.so
# 	libm.so.6 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libm.so.6
# 	liblz4.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblz4.so.1
# 	liblzma.so.5 (libc6,x86-64) => /lib/x86_64-linux-gnu/liblzma.so.5
# 	liblsan.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblsan.so.0
# 	libldap_r-2.4.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libldap_r-2.4.so.2
# 	liblber-2.4.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblber-2.4.so.2
# 	liblapack_atlas.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblapack_atlas.so.3
# 	liblapack_atlas.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblapack_atlas.so
# 	liblapack.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblapack.so.3
# 	liblapack.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/liblapack.so
# 	libk5crypto.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libk5crypto.so.3
# 	libksba.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libksba.so.8
# 	libkrb5support.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libkrb5support.so.0
# 	libkrb5.so.26 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libkrb5.so.26
# 	libkrb5.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libkrb5.so.3
# 	libkeyutils.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libkeyutils.so.1
# 	libjpeg.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libjpeg.so.8
# 	libjpeg.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libjpeg.so
# 	libitm.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libitm.so.1
# 	libisl.so.15 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libisl.so.15
# 	libidn2.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libidn2.so.0
# 	libidn.so.11 (libc6,x86-64) => /lib/x86_64-linux-gnu/libidn.so.11
# 	libicuuc.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicuuc.so.57
# 	libicuuc.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicuuc.so
# 	libicutu.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicutu.so.57
# 	libicutu.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicutu.so
# 	libicutest.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicutest.so.57
# 	libicutest.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicutest.so
# 	libiculx.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libiculx.so.57
# 	libiculx.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libiculx.so
# 	libicule.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicule.so.57
# 	libicule.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicule.so
# 	libicui18n.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicui18n.so.57
# 	libicui18n.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicui18n.so
# 	libicuio.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicuio.so.57
# 	libicuio.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicuio.so
# 	libicudata.so.57 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicudata.so.57
# 	libicudata.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libicudata.so
# 	libhx509.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhx509.so.5
# 	libhogweed.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhogweed.so.4
# 	libhistory.so.7 (libc6,x86-64) => /lib/x86_64-linux-gnu/libhistory.so.7
# 	libheimntlm.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libheimntlm.so.0
# 	libheimbase.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libheimbase.so.1
# 	libhdf5_serialhl_fortran.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serialhl_fortran.so.100
# 	libhdf5_serialhl_fortran.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serialhl_fortran.so
# 	libhdf5_serial_hl.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial_hl.so.100
# 	libhdf5_serial_hl.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial_hl.so
# 	libhdf5_serial_fortran.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial_fortran.so.100
# 	libhdf5_serial_fortran.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial_fortran.so
# 	libhdf5_serial.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial.so.100
# 	libhdf5_serial.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_serial.so
# 	libhdf5_hl_cpp.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_hl_cpp.so.100
# 	libhdf5_hl_cpp.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_hl_cpp.so
# 	libhdf5_cpp.so.100 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_cpp.so.100
# 	libhdf5_cpp.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhdf5_cpp.so
# 	libhcrypto.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libhcrypto.so.4
# 	libgthread-2.0.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgthread-2.0.so.0
# 	libgssapi_krb5.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgssapi_krb5.so.2
# 	libgssapi.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgssapi.so.3
# 	libgpg-error.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libgpg-error.so.0
# 	libgomp.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgomp.so.1
# 	libgobject-2.0.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgobject-2.0.so.0
# 	libgnutls.so.30 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgnutls.so.30
# 	libgmp.so.10 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgmp.so.10
# 	libgmodule-2.0.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgmodule-2.0.so.0
# 	libglib-2.0.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libglib-2.0.so.0
# 	libgio-2.0.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgio-2.0.so.0
# 	libgfortran.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgfortran.so.4
# 	libgdbm_compat.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgdbm_compat.so.3
# 	libgdbm.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libgdbm.so.3
# 	libgcrypt.so.20 (libc6,x86-64) => /lib/x86_64-linux-gnu/libgcrypt.so.20
# 	libgcc_s.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libgcc_s.so.1
# 	libf77blas.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libf77blas.so.3
# 	libf77blas.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libf77blas.so
# 	libfreetype.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libfreetype.so.6
# 	libfreetype.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libfreetype.so
# 	libformw.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libformw.so.5
# 	libform.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libform.so.5
# 	libfontconfig.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libfontconfig.so.1
# 	libfontconfig.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libfontconfig.so
# 	libffi.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libffi.so.6
# 	libfdisk.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libfdisk.so.1
# 	libe2p.so.2 (libc6,x86-64) => /lib/x86_64-linux-gnu/libe2p.so.2
# 	libext2fs.so.2 (libc6,x86-64) => /lib/x86_64-linux-gnu/libext2fs.so.2
# 	libexpatw.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libexpatw.so.1
# 	libexpatw.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libexpatw.so
# 	libexpat.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libexpat.so.1
# 	libexpat.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libexpat.so
# 	libedit.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libedit.so.2
# 	libdl.so.2 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libdl.so.2
# 	libdl.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libdl.so
# 	libdebconfclient.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libdebconfclient.so.0
# 	libdb-5.3.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libdb-5.3.so
# 	libcusolver.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcusolver.so.8.0
# 	libcurl.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcurl.so.4
# 	libcurl-gnutls.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcurl-gnutls.so.4
# 	libcurand.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcurand.so.8.0
# 	libcufftw.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcufftw.so.8.0
# 	libcufft.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcufft.so.8.0
# 	libcudart.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcudart.so.8.0
# 	libcublas.so.8.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcublas.so.8.0
# 	libcrypto.so.1.0.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libcrypto.so.1.0.0
# 	libcrypt.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libcrypt.so.1
# 	libcrypt.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libcrypt.so
# 	libcom_err.so.2 (libc6,x86-64) => /lib/x86_64-linux-gnu/libcom_err.so.2
# 	libcilkrts.so.5 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcilkrts.so.5
# 	libcidn.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libcidn.so.1
# 	libcidn.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libcidn.so
# 	libcc1.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcc1.so.0
# 	libcblas.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcblas.so.3
# 	libcblas.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libcblas.so
# 	libcap-ng.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libcap-ng.so.0
# 	libc.so.6 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libc.so.6
# 	libbz2.so.1.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libbz2.so.1.0
# 	libbsd.so.0 (libc6,x86-64) => /lib/x86_64-linux-gnu/libbsd.so.0
# 	libblkid.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libblkid.so.1
# 	libblas.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libblas.so.3
# 	libblas.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libblas.so
# 	libbfd-2.29.1-system.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libbfd-2.29.1-system.so
# 	libaudit.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libaudit.so.1
# 	libattr.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libattr.so.1
# 	libatomic.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libatomic.so.1
# 	libatlas.so.3 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libatlas.so.3
# 	libatlas.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libatlas.so
# 	libassuan.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libassuan.so.0
# 	libasn1.so.8 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libasn1.so.8
# 	libasan.so.4 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libasan.so.4
# 	libapt-private.so.0.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libapt-private.so.0.0
# 	libapt-pkg.so.5.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libapt-pkg.so.5.0
# 	libapt-inst.so.2.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libapt-inst.so.2.0
# 	libanl.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libanl.so.1
# 	libanl.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libanl.so
# 	libaec.so.0 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libaec.so.0
# 	libaec.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libaec.so
# 	libacl.so.1 (libc6,x86-64) => /lib/x86_64-linux-gnu/libacl.so.1
# 	libX11.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libX11.so.6
# 	libX11.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libX11.so
# 	libXss.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXss.so.1
# 	libXrender.so.1 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXrender.so.1
# 	libXrender.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXrender.so
# 	libXft.so.2 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXft.so.2
# 	libXft.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXft.so
# 	libXext.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXext.so.6
# 	libXdmcp.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXdmcp.so.6
# 	libXdmcp.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXdmcp.so
# 	libXau.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXau.so.6
# 	libXau.so (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libXau.so
# 	libSegFault.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libSegFault.so
# 	libSM.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libSM.so.6
# 	libICE.so.6 (libc6,x86-64) => /usr/lib/x86_64-linux-gnu/libICE.so.6
# 	libBrokenLocale.so.1 (libc6,x86-64, OS ABI: Linux 3.2.0) => /lib/x86_64-linux-gnu/libBrokenLocale.so.1
# 	libBrokenLocale.so (libc6,x86-64, OS ABI: Linux 3.2.0) => /usr/lib/x86_64-linux-gnu/libBrokenLocale.so
# 	libBLTlite.2.5.so.8.6 (libc6,x86-64) => /usr/lib/libBLTlite.2.5.so.8.6
# 	libBLT.2.5.so.8.6 (libc6,x86-64) => /usr/lib/libBLT.2.5.so.8.6
# 	ld-linux-x86-64.so.2 (libc6,x86-64) => /lib/x86_64-linux-gnu/ld-linux-x86-64.so.2

# %%
# !pip freeze
# Out:
# absl-py==0.2.2
# altair==2.0.1
# astor==0.6.2
# beautifulsoup4==4.6.0
# bleach==1.5.0
# cachetools==2.1.0
# certifi==2018.4.16
# chardet==3.0.4
# crcmod==1.7
# cycler==0.10.0
# Cython==0.28.3
# decorator==4.3.0
# entrypoints==0.2.3
# fortran-magic==0.7
# future==0.16.0
# gast==0.2.0
# google-api-core==1.1.2
# google-api-python-client==1.6.7
# google-auth==1.4.1
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.2.0
# google-cloud-bigquery==1.1.0
# google-cloud-core==0.28.1
# google-cloud-language==1.0.2
# google-cloud-storage==1.8.0
# google-cloud-translate==1.3.1
# google-colab==0.0.1a1
# google-resumable-media==0.3.1
# googleapis-common-protos==1.5.3
# grpcio==1.12.1
# h5py==2.7.1
# html5lib==0.9999999
# httplib2==0.11.3
# idna==2.6
# ipykernel==4.6.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# Jinja2==2.10
# jsonschema==2.6.0
# jupyter-client==5.2.3
# jupyter-core==4.4.0
# Keras==2.1.6
# Markdown==2.6.11
# MarkupSafe==1.0
# matplotlib==2.1.2
# mistune==0.8.3
# mpmath==1.0.0
# nbconvert==5.3.1
# nbformat==4.4.0
# networkx==2.1
# nltk==3.2.5
# notebook==5.2.2
# numpy==1.14.3
# oauth2client==4.1.2
# oauthlib==2.0.7
# olefile==0.45.1
# opencv-python==3.4.1.15
# pandas==0.22.0
# pandas-gbq==0.4.1
# pandocfilters==1.4.2
# patsy==0.5.0
# pexpect==4.5.0
# pickleshare==0.7.4
# Pillow==4.0.0
# plotly==1.12.12
# portpicker==1.2.0
# prettytable==0.7.2
# prompt-toolkit==1.0.15
# protobuf==3.5.2.post1
# psutil==5.4.5
# ptyprocess==0.5.2
# pyasn1==0.4.2
# pyasn1-modules==0.2.1
# Pygments==2.1.3
# pyparsing==2.2.0
# python-dateutil==2.5.3
# pytz==2018.4
# PyWavelets==0.5.2
# PyYAML==3.12
# pyzmq==16.0.4
# requests==2.18.4
# requests-oauthlib==0.8.0
# rsa==3.4.2
# scikit-image==0.13.1
# scikit-learn==0.19.1
# scipy==0.19.1
# seaborn==0.7.1
# simplegeneric==0.8.1
# six==1.11.0
# SQLAlchemy==1.2.8
# sqlparse==0.2.4
# statsmodels==0.8.0
# sympy==1.1.1
# tensorboard==1.8.0
# tensorflow==1.8.0
# tensorflow-hub==0.1.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.3.1
# toolz==0.9.0
# tornado==4.5.3
# traitlets==4.3.2
# typing==3.6.4
# uritemplate==3.0.0
# urllib3==1.22
# vega-datasets==0.5.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# xgboost==0.7.post4

# %%
# !pip install watermark
# Out:
# Collecting watermark
#   Downloading https://files.pythonhosted.org/packages/33/ec/4b5b4674bdccebdf2c1de6a597579adac99f2a160ae402671eaebd3521f4/watermark-1.6.0-py3-none-any.whl
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from watermark)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->watermark)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->watermark)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->watermark)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->watermark)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->watermark)
# Installing collected packages: watermark
# Successfully installed watermark-1.6.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# %load_ext watermark
# %watermark -v -m -p tensorflow,numpy -g
# Out:
# CPython 3.6.3
# IPython 5.5.0
#
# tensorflow 1.7.0
# numpy 1.14.2
#
# compiler   : GCC 7.2.0
# system     : Linux
# release    : 4.4.111+
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 2
# interpreter: 64bit
# Git hash   :

# %%
# From https://stackoverflow.com/questions/48750199/google-colaboratory-misleading-information-about-its-gpu-only-5-ram-available
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn't guaranteed
gpu = GPUs[0]

def printm():
  process = psutil.Process(os.getpid())
  print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " I Proc size: " + humanize.naturalsize( process.memory_info().rss))
  print('GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB'.format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))

printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/45/99/837428d26b47ebd6b66d6e1b180e98ec4a557767a93a81a02ea9d6242611/GPUtil-1.3.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil)
# Building wheels for collected packages: gputil
# done
#   Stored in directory: /content/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.3.0
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting humanize
#   Downloading https://files.pythonhosted.org/packages/8c/e0/e512e4ac6d091fc990bbe13f9e0378f34cf6eecd1c6c268c9e598dcf5bb9/humanize-0.5.1.tar.gz
# Building wheels for collected packages: humanize
# done
#   Stored in directory: /content/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# Installing collected packages: humanize
# Successfully installed humanize-0.5.1
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Gen RAM Free: 12.2 GB  I Proc size: 243.9 MB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
# !nvidia-smi
# Out:
# Wed Apr 25 14:06:44 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P8    30W / 149W |      0MiB / 11439MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !ps -ef|grep python
# Out:
# root        89    79  0 13:42 ?        00:00:04 /usr/bin/python2 /usr/local/bin/jupyter-notebook -y --no-browser --log-level=DEBUG --debug --NotebookApp.allow_origin="*" --NotebookApp.log_format="%(message)s" --NotebookApp.token= --Session.key="" --Session.keyfile="" --ContentsManager.untitled_directory="Untitled Folder" --ContentsManager.untitled_file="Untitled File" --ContentsManager.untitled_notebook="Untitled Notebook" --NotebookNotary.algorithm="sha1" --KernelManager.autorestart=True --MultiKernelManager.default_kernel_name="python2" --ip="127.0.0.1" --port=9000 --port-retries=0 --notebook-dir="/content" --NotebookNotary.algorithm=sha256 --NotebookNotary.secret_file=/content/datalab/.config/notary_secret --NotebookApp.base_url=/tun/m/gpu-3b69a941-2394-49f6-a0e9-ae156c019262/
# root       110    89  0 13:42 ?        00:00:10 /usr/bin/python -m ipykernel_launcher -f /content/.local/share/jupyter/runtime/kernel-df60f02e-fa18-4c12-a063-3902d23590ed.json
# root       181    89 43 14:06 ?        00:00:14 /usr/bin/python3 -m ipykernel_launcher -f /content/.local/share/jupyter/runtime/kernel-a52ee857-1d7c-42e0-bf02-3029f0820436.json
# root       256   181 94 14:06 pts/0    00:00:00 /bin/sh -c ps -ef|grep python
# root       258   256  0 14:06 pts/0    00:00:00 grep python
