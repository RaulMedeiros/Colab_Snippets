# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/RaulMedeiros/Colab_Snippets/blob/master/UPLOAD_AND_DONWLOAD_FILE_FROM_PC.ipynb)

# %% [markdown]
# # UPLOAD FILE FROM PC

# %%
#Uploading the Dataset 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6f6c77f-be31-43bf-a8fa-0c950e5cc3c2" name="files[]" multiple disabled />
#      <output id="result-a6f6c77f-be31-43bf-a8fa-0c950e5cc3c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving c1_111.jpeg to c1_111.jpeg

# %%
# !ls
# Out:
# c1_111.jpeg  datalab  dataset

# %% [markdown]
# # TEST

# %%
# !ls
img_path = "c1_111.jpeg"
# Out:
# c1_111.jpeg  datalab  dataset

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread(img_path)
plt.imshow(img)
plt.show()

# %% [markdown]
# # DOWNLOAD FILE

# %%
files.download(img_path)
