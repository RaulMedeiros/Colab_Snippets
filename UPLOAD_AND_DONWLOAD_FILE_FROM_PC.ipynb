# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/RaulMedeiros/Colab_Snippets/blob/master/UPLOAD_AND_DONWLOAD_FILE_FROM_PC.ipynb)

# %% [markdown]
# # UPLOAD FILE FROM PC

# %%
#Uploading the Dataset 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2579a240-4cfa-4873-890c-8d50e5d3d939" name="files[]" multiple disabled />
#      <output id="result-2579a240-4cfa-4873-890c-8d50e5d3d939">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ai.jpg to ai.jpg

# %% [markdown]
# # TEST

# %%
# !ls
img_path = "ai.jpg"
# Out:
# ai.jpg	datalab  sample_data

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread(img_path)
plt.grid(False)
plt.imshow(img)
plt.show()

# %% [markdown]
# # DOWNLOAD FILE

# %%
files.download(img_path)
